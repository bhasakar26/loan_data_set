# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r'C:\Users\Bhaskar\loan_data.csv')

# %%
data.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
data.shape
# Out:
# (9578, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
data.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
data.columns = ['Credit_Policy', 'Loan_Purpose', 'Interest_Rate', 'Installment', 'Annual_Income_Log_Report', 
                'Debt_to_Income_Ratio', 'FICO_Score', 'Days_with_Credit_Line', 'Revolving_balance', 'Revolving_utilization rate', 
                'Inquiries_in_last_Six_Months', 'Delinquency_Frequency', 'Public_Derogatory_Records', 'Will_Default']

# %%
data.head()
# Out:
#    Credit_Policy        Loan_Purpose  Interest_Rate  Installment  \
# 0              1  debt_consolidation         0.1189       829.10
# 1              1         credit_card         0.1071       228.22
# 2              1  debt_consolidation         0.1357       366.86
# 3              1  debt_consolidation         0.1008       162.34
# 4              1         credit_card         0.1426       102.92
#
#    Annual_Income_Log_Report  Debt_to_Income_Ratio  FICO_Score  \
# 0                 11.350407                 19.48         737
# 1                 11.082143                 14.29         707
# 2                 10.373491                 11.63         682
# 3                 11.350407                  8.10         712
# 4                 11.299732                 14.97         667
#
#    Days_with_Credit_Line  Revolving_balance  Revolving_utilization rate  \
# 0            5639.958333              28854                        52.1
# ...

# %%
plt.figure(figsize=(30,6))
sns.countplot(data = data, x = data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Credit_Policy                 9578 non-null   int64
#  1   Loan_Purpose                  9578 non-null   object
#  2   Interest_Rate                 9578 non-null   float64
#  3   Installment                   9578 non-null   float64
#  4   Annual_Income_Log_Report      9578 non-null   float64
#  5   Debt_to_Income_Ratio          9578 non-null   float64
#  6   FICO_Score                    9578 non-null   int64
#  7   Days_with_Credit_Line         9578 non-null   float64
#  8   Revolving_balance             9578 non-null   int64
#  9   Revolving_utilization rate    9578 non-null   float64
#  10  Inquiries_in_last_Six_Months  9578 non-null   int64
#  11  Delinquency_Frequency         9578 non-null   int64
# ...

# %%
data['Loan_Purpose']
# Out:
# 0       debt_consolidation
# 1              credit_card
# 2       debt_consolidation
# 3       debt_consolidation
# 4              credit_card
#                ...
# 9573             all_other
# 9574             all_other
# 9575    debt_consolidation
# 9576      home_improvement
# 9577    debt_consolidation
# Name: Loan_Purpose, Length: 9578, dtype: object

# %%
data['Loan_Purpose'].unique()
# Out:
# array(['debt_consolidation', 'credit_card', 'all_other',
#        'home_improvement', 'small_business', 'major_purchase',
#        'educational'], dtype=object)

# %%
len(data['Loan_Purpose'].unique())
# Out:
# 7

# %%
data['Loan_Purpose'].value_counts()
# Out:
# debt_consolidation    3957
# all_other             2331
# credit_card           1262
# home_improvement       629
# small_business         619
# major_purchase         437
# educational            343
# Name: Loan_Purpose, dtype: int64

# %%
plt.figure(figsize=(27,7))
sns.countplot(data.Loan_Purpose)
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Loan_Purpose', ylabel='count'>

# %%
educational_loan=data.loc[data.Loan_Purpose=='educational']
educational_loan
# Out:
#       Credit_Policy Loan_Purpose  Interest_Rate  Installment  \
# 46                1  educational         0.0775       168.60
# 53                1  educational         0.0996       112.87
# 77                1  educational         0.0743       124.31
# 115               1  educational         0.1059       195.27
# 140               1  educational         0.1249       100.35
# ...             ...          ...            ...          ...
# 9439              0  educational         0.1600       527.36
# 9468              0  educational         0.1461       168.93
# 9498              0  educational         0.1426       267.59
# 9505              0  educational         0.1287       121.08
# 9547              0  educational         0.1607       147.82
#
#       Annual_Income_Log_Report  Debt_to_Income_Ratio  FICO_Score  \
# 46                    8.987197                  3.00         762
# 53                    9.510445                 16.44         712
# ...

# %%
educational_loan1=data.groupby(by=['Credit_Policy']).count()
educational_loan1
# Out:
#                Loan_Purpose  Interest_Rate  Installment  \
# Credit_Policy
# 0                      1868           1868         1868
# 1                      7710           7710         7710
#
#                Annual_Income_Log_Report  Debt_to_Income_Ratio  FICO_Score  \
# Credit_Policy
# 0                                  1868                  1868        1868
# 1                                  7710                  7710        7710
#
#                Days_with_Credit_Line  Revolving_balance  \
# Credit_Policy
# 0                               1868               1868
# 1                               7710               7710
#
#                Revolving_utilization rate  Inquiries_in_last_Six_Months  \
# Credit_Policy
# 0                                    1868                          1868
# 1                                    7710                          7710
#
#                Delinquency_Frequency  Public_Derogatory_Records  Will_Default
# Credit_Policy
# ...

# %%
educational_loan.mean()
# Out:
# Credit_Policy                       0.740525
# Interest_Rate                       0.119907
# Installment                       217.547201
# Annual_Income_Log_Report           10.549956
# Debt_to_Income_Ratio               11.344927
# FICO_Score                        708.282799
# Days_with_Credit_Line            4008.595724
# Revolving_balance               10828.897959
# Revolving_utilization rate         38.801166
# Inquiries_in_last_Six_Months        1.854227
# Delinquency_Frequency               0.157434
# Public_Derogatory_Records           0.043732
# Will_Default                        0.201166
# dtype: float64

# %%
sns.distplot(educational_loan['Installment'])
plt.title("Educational_loan")
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Educational_loan')

# %%
sns.relplot(x='Credit_Policy',y='Interest_Rate',hue='Credit_Policy',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x='Credit_Policy',y='Annual_Income_Log_Report',hue='Credit_Policy',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
corrmat=data.corr()
corrmat
# Out:
#                               Credit_Policy  Interest_Rate  Installment  \
# Credit_Policy                      1.000000      -0.294089     0.058770
# Interest_Rate                     -0.294089       1.000000     0.276140
# Installment                        0.058770       0.276140     1.000000
# Annual_Income_Log_Report           0.034906       0.056383     0.448102
# Debt_to_Income_Ratio              -0.090901       0.220006     0.050202
# FICO_Score                         0.348319      -0.714821     0.086039
# Days_with_Credit_Line              0.099026      -0.124022     0.183297
# Revolving_balance                 -0.187518       0.092527     0.233625
# Revolving_utilization rate        -0.104095       0.464837     0.081356
# Inquiries_in_last_Six_Months      -0.535511       0.202780    -0.010419
# Delinquency_Frequency             -0.076318       0.156079    -0.004368
# Public_Derogatory_Records         -0.054243       0.098162    -0.032760
# ...

# %%
plt.figure(figsize=(20,20), dpi=100)
sns.heatmap(corrmat,annot=True)
plt.show()
